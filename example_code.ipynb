# %%
# Initialisation
import os
import requests
import json
import pandas as pd
import urllib.parse as url
from dotenv import load_dotenv

# %%
# Load env variables
load_dotenv()
api_key = os.getenv("DOMAIN_API_KEY")

# %%
# This is an example on how to make a request to the domain.com.au api
# First lets pretend we got an address as a full string and want to get address _suggest
address_string = "unit 15 10 12 third avenue campsie"
# The urllib.parse library lets us convert string into url text
address_url = url.quote(address_string)

# We now combine our data into the request url. The API I'm using has the below format. I set page size manually here.
# https://api.domain.com.au/v1/properties/_suggest?terms=(address)&pageSize=(number up to 20)&api_key=(your api)
# If you want to use a different get request, find the URL you need and format the request_url. If you need help you can ask me, Kevin
request_url = f"https://api.domain.com.au/v1/properties/_suggest?terms={address_url}&pageSize=1&api_key={api_key}"
get_request = requests.get(request_url)

# Data formatting
data = get_request.json()
data_indented = json.dumps(data, indent=4)
# Print data
print(data_indented)
# Out:
# [
#     {
#         "address": "15/10-12 Third Avenue, Campsie NSW 2194",
#         "addressComponents": {
#             "unitNumber": "15",
#             "streetNumber": "10-12",
#             "streetName": "Third",
#             "streetType": "Av",
#             "streetTypeLong": "Avenue",
#             "suburb": "Campsie",
#             "postCode": "2194",
#             "state": "NSW"
#         },
#         "id": "AQ-5616-QU",
#         "relativeScore": 100
#     }
# ]

# %%
address_data = data[0]["addressComponents"]
# Extract location id to use as global index for all dfs regarding this location. There may be a better way to do this
location_id = data[0]["id"]
address_df = pd.DataFrame(address_data,index=[location_id])
address_df.head()
# Out:
#            unitNumber streetNumber streetName streetType streetTypeLong  \
# AQ-5616-QU         15        10-12      Third         Av         Avenue
#
#              suburb postCode state
# AQ-5616-QU  Campsie     2194   NSW

# %%
# Address locators: this request will return a unique identifier for the following address levels:
# Address, street, suburb, postcode

# https://api.domain.com.au/v1/addressLocators?searchLevel=Suburb&unitNumber=15&streetNumber=10-12&streetName=Third&streetType=Avenue&suburb=Campsie&state=NSW&postcode=2194
# Unit is not always required, but every other field is.
# If there is no unit (building is a house or w/e), unit needs to = None
level = "Address"
if "unitNumber" in address_df.columns:
    unit = address_df.iloc[0]["unitNumber"]
else:
    unit = None
street_num = address_df.iloc[0]["streetNumber"]
street_name = address_df.iloc[0]["streetName"]
street_type = address_df.iloc[0]["streetType"]
suburb = address_df.iloc[0]["suburb"]
post_code = address_df.iloc[0]["postCode"]
state = address_df.iloc[0]["state"]

# Sample of request URL. We cant use docstring as it will put \n's on every line break
"""
https://api.domain.com.au/v1/addressLocators?
searchLevel={level}&
unitNumber={unit}&
streetNumber={street_num}&
streetName={street_name}&
streetType={street_type}&
suburb={suburb}&
state={state}&
postcode={post_code}&
api_key={api_key}
"""
# Check if building is actually a unit
if not unit:
    request_url = f"https://api.domain.com.au/v1/addressLocators?searchLevel={level}&streetNumber={street_num}&streetName={street_name}&streetType={street_type}&suburb={suburb}&state={state}&postcode={post_code}&api_key={api_key}"
else:
    request_url = f"https://api.domain.com.au/v1/addressLocators?searchLevel={level}&unitNumber={unit}&streetNumber={street_num}&streetName={street_name}&streetType={street_type}&suburb={suburb}&state={state}&postcode={post_code}&api_key={api_key}"
    
get_request = requests.get(request_url)

# Data formatting
data = get_request.json()
data_indented = json.dumps(data, indent=4)
# Print data
print(data_indented)
# Out:
# [
#     {
#         "types": [
#             "Address"
#         ],
#         "addressComponents": [
#             {
#                 "component": "StreetNumber",
#                 "shortName": "10-12"
#             },
#             {
#                 "component": "UnitNumber",
#                 "shortName": "15"
#             },
#             {
#                 "component": "StreetName",
#                 "shortName": "Third"
#             },
#             {
#                 "component": "StreetType",
#                 "shortName": "Av"
#             },
#             {
#                 "component": "Suburb",
#                 "shortName": "Campsie"
#             },
#             {
#                 "component": "Postcode",
#                 "shortName": "2194"
#             },
#             {
#                 "component": "State",
#                 "shortName": "NSW"
#             }
#         ],
#         "ids": [
#             {
#                 "level": "Address",
#                 "id": 5457477
#             },
#             {
#                 "level": "Street",
#                 "id": 1283352
#             },
#             {
#                 "level": "Suburb",
#                 "id": 8562
#             },
#             {
#                 "level": "Postcode",
#                 "id": 1752
#             }
#         ]
#     }
# ]

# %%
# Get id data as df
# ID data is given as a list of dicts. To create a df out of this we need to combine the dicts into one
combined_id_data = {}
for loc_id in id_data:
    combined_id_data.update({loc_id["level"]+" id": loc_id["id"]})


id_df = pd.DataFrame(combined_id_data, index=[location_id])
id_df.head()
# Out:
#             Address id  Street id  Suburb id  Postcode id
# AQ-5616-QU     5457477    1283352       8562         1752

# %%
# Theoretical example where we combined with the df above
combined_df = pd.concat([address_df, id_df], axis="columns", join="outer")
combined_df
# Out:
#            unitNumber streetNumber streetName streetType streetTypeLong  \
# AQ-5616-QU         15        10-12      Third         Av         Avenue
#
#              suburb postCode state  Address id  Street id  Suburb id  \
# AQ-5616-QU  Campsie     2194   NSW     5457477    1283352       8562
#
#             Postcode id
# AQ-5616-QU         1752

# %%
# Location profiles: this request gives an info dump of a given location based on the id given. ID must come from Address Locator request
# https://api.domain.com.au/v1/locations/profiles/{id from any level}?api_key={api_key}
loc_id = id_df.iloc[0]["Postcode id"]

request_url = f"https://api.domain.com.au/v1/locations/profiles/{loc_id}?api_key={api_key}"
get_request = requests.get(request_url)
data = get_request.json()
data_indented = json.dumps(data, indent=4)
# Print data
print(data_indented)
# Out:
# {
#     "domainLocationId": 1752,
#     "postcode": "2093",
#     "pfLocationId": "NSW150",
#     "surroundingSuburbs": [
#         {
#             "name": "Clontarf",
#             "urlSlug": "clontarf-nsw-2093"
#         },
#         {
#             "name": "Balgowlah Heights",
#             "urlSlug": "balgowlah-heights-nsw-2093"
#         },
#         {
#             "name": "Fairlight",
#             "urlSlug": "fairlight-nsw-2094"
#         },
#         {
#             "name": "Seaforth",
#             "urlSlug": "seaforth-nsw-2092"
#         },
#         {
#             "name": "North Balgowlah",
#             "urlSlug": "north-balgowlah-nsw-2093"
#         },
#         {
#             "name": "Manly Vale",
#             "urlSlug": "manly-vale-nsw-2093"
#         },
#         {
#             "name": "Allambie",
#             "urlSlug": "allambie-nsw-2100"
#         }
#     ],
#     "urlSlug": "balgowlah-nsw-2093",
#     "suburbName": "Balgowlah",
#     "data": {
#         "studiosForRent": 0,
#         "terracedHousesForSale": 0,
#         "semiDetachedHousesForSale": 2,
#         "townhousesForRent": 1,
#         "apartmentsAndUnitsForSale": 6,
#         "apartmentsAndUnitsForRent": 17,
#         "villasForSale": 0,
#         "duplexesForSale": 1,
#         "semiDetachedHousesForRent": 1,
#         "studiosForSale": 0,
#         "singlePercentage": 0.4755669115298627,
#         "mostCommonAgeBracket": "40 to 59",
#         "renterPercentage": 0.32470187393526406,
#         "penthousesForSale": 0,
#         "villasForRent": 0,
#         "duplexesForRent": 0,
#         "housesForSale": 6,
#         "ownerOccupierPercentage": 0.6752981260647359,
#         "propertyCategories": [
#             {
#                 "luxuryLevelPrice": 0.0,
#                 "numberSold": 7,
#                 "estimatedRepayments": 0.0,
#                 "forSale": 1,
#                 "medianSoldPrice": 0.0,
#                 "medianRentPrice": 725.0,
#                 "daysOnMarket": 0.0,
#                 "bedrooms": 2,
#                 "forRent": 1,
#                 "entryLevelPrice": 0.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 1464000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 14,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 1450000.0,
#                         "annualGrowth": -0.009562841530054645,
#                         "numberSold": 12,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 9,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 4,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 1343000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 12,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 7,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.0,
#                 "propertyCategory": "House"
#             },
#             {
#                 "luxuryLevelPrice": 3750000.0,
#                 "numberSold": 41,
#                 "estimatedRepayments": 7525.438040919192,
#                 "forSale": 1,
#                 "medianSoldPrice": 2260000.0,
#                 "medianRentPrice": 1040.0,
#                 "daysOnMarket": 58.0,
#                 "bedrooms": 3,
#                 "forRent": 2,
#                 "entryLevelPrice": 1549000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 1560000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 40,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 1820000.0,
#                         "annualGrowth": 0.16666666666666666,
#                         "numberSold": 55,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 1875000.0,
#                         "annualGrowth": 0.03021978021978022,
#                         "numberSold": 47,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 1800000.0,
#                         "annualGrowth": -0.04,
#                         "numberSold": 39,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 1870000.0,
#                         "annualGrowth": 0.03888888888888889,
#                         "numberSold": 41,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 2260000.0,
#                         "annualGrowth": 0.20855614973262032,
#                         "numberSold": 41,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.9285714285714286,
#                 "propertyCategory": "House"
#             },
#             {
#                 "luxuryLevelPrice": 5230000.0,
#                 "numberSold": 23,
#                 "estimatedRepayments": 9533.331465111347,
#                 "forSale": 4,
#                 "medianSoldPrice": 2863000.0,
#                 "medianRentPrice": 1600.0,
#                 "daysOnMarket": 13.0,
#                 "bedrooms": 4,
#                 "forRent": 1,
#                 "entryLevelPrice": 1700000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 2208000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 27,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 2225000.0,
#                         "annualGrowth": 0.007699275362318841,
#                         "numberSold": 17,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 2213000.0,
#                         "annualGrowth": -0.005393258426966292,
#                         "numberSold": 26,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 2200000.0,
#                         "annualGrowth": -0.00587437867148667,
#                         "numberSold": 15,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 2420000.0,
#                         "annualGrowth": 0.1,
#                         "numberSold": 21,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 2863000.0,
#                         "annualGrowth": 0.18305785123966942,
#                         "numberSold": 23,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.8125,
#                 "propertyCategory": "House"
#             },
#             {
#                 "luxuryLevelPrice": 5000000.0,
#                 "numberSold": 14,
#                 "estimatedRepayments": 12536.847001796794,
#                 "forSale": 0,
#                 "medianSoldPrice": 3765000.0,
#                 "medianRentPrice": 0.0,
#                 "daysOnMarket": 0.0,
#                 "bedrooms": 5,
#                 "forRent": 0,
#                 "entryLevelPrice": 2710000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 6,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 7,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 5,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 7,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 2932000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 14,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 3765000.0,
#                         "annualGrowth": 0.284106412005457,
#                         "numberSold": 14,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.0,
#                 "propertyCategory": "House"
#             },
#             {
#                 "luxuryLevelPrice": 1200000.0,
#                 "numberSold": 11,
#                 "estimatedRepayments": 2996.855857003218,
#                 "forSale": 1,
#                 "medianSoldPrice": 900000.0,
#                 "medianRentPrice": 588.0,
#                 "daysOnMarket": 56.0,
#                 "bedrooms": 1,
#                 "forRent": 7,
#                 "entryLevelPrice": 565000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 705000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 12,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 818000.0,
#                         "annualGrowth": 0.16028368794326242,
#                         "numberSold": 16,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 953000.0,
#                         "annualGrowth": 0.16503667481662593,
#                         "numberSold": 12,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 9,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 0.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 8,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 900000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 11,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.0,
#                 "propertyCategory": "Unit"
#             },
#             {
#                 "luxuryLevelPrice": 1920000.0,
#                 "numberSold": 59,
#                 "estimatedRepayments": 3329.8398411146864,
#                 "forSale": 5,
#                 "medianSoldPrice": 1000000.0,
#                 "medianRentPrice": 600.0,
#                 "daysOnMarket": 35.0,
#                 "bedrooms": 2,
#                 "forRent": 8,
#                 "entryLevelPrice": 737000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 780000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 51,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 919000.0,
#                         "annualGrowth": 0.1782051282051282,
#                         "numberSold": 46,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 815000.0,
#                         "annualGrowth": -0.11316648531011969,
#                         "numberSold": 43,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 770000.0,
#                         "annualGrowth": -0.05521472392638037,
#                         "numberSold": 44,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 900000.0,
#                         "annualGrowth": 0.16883116883116883,
#                         "numberSold": 35,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 1000000.0,
#                         "annualGrowth": 0.1111111111111111,
#                         "numberSold": 59,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.8064516129032258,
#                 "propertyCategory": "Unit"
#             },
#             {
#                 "luxuryLevelPrice": 3450000.0,
#                 "numberSold": 19,
#                 "estimatedRepayments": 5993.711714006436,
#                 "forSale": 0,
#                 "medianSoldPrice": 1800000.0,
#                 "medianRentPrice": 900.0,
#                 "daysOnMarket": 0.0,
#                 "bedrooms": 3,
#                 "forRent": 2,
#                 "entryLevelPrice": 1205000.0,
#                 "salesGrowthList": [
#                     {
#                         "medianSoldPrice": 1215000.0,
#                         "annualGrowth": 0.0,
#                         "numberSold": 21,
#                         "year": 2016
#                     },
#                     {
#                         "medianSoldPrice": 1615000.0,
#                         "annualGrowth": 0.3292181069958848,
#                         "numberSold": 20,
#                         "year": 2017
#                     },
#                     {
#                         "medianSoldPrice": 1625000.0,
#                         "annualGrowth": 0.006191950464396285,
#                         "numberSold": 13,
#                         "year": 2018
#                     },
#                     {
#                         "medianSoldPrice": 1255000.0,
#                         "annualGrowth": -0.2276923076923077,
#                         "numberSold": 15,
#                         "year": 2019
#                     },
#                     {
#                         "medianSoldPrice": 1556000.0,
#                         "annualGrowth": 0.2398406374501992,
#                         "numberSold": 18,
#                         "year": 2020
#                     },
#                     {
#                         "medianSoldPrice": 1800000.0,
#                         "annualGrowth": 0.15681233933161953,
#                         "numberSold": 19,
#                         "year": 2021
#                     }
#                 ],
#                 "auctionClearanceRate": 0.5789473684210527,
#                 "propertyCategory": "Unit"
#             }
#         ],
#         "population": 7980.0,
#         "penthousesForRent": 0,
#         "townhousesForSale": 0,
#         "terracedHousesForRent": 0,
#         "marriedPercentage": 0.5244330884701374,
#         "housesForRent": 5,
#         "blockOfUnitsForSale": 0
#     },
#     "apmLocationId": 1752,
#     "areaName": "Northern Beaches",
#     "regionName": "Sydney Region",
#     "state": "NSW"
# }

# %%
loc_id
# Out:
# 1752
